# %% [markdown]
# # N°36 — Pandas 1: abrir y mirar

# %% [markdown]
# **Objetivo de la sesión:** Abrir un CSV real con pandas, mirarlo, elegir columnas, y contar/filtrar vacíos.

# %% [markdown]
# ## ✅ Contenido que debe quedar consolidado al cierre
#
# - `pd.read_csv(...)` (con `sep=`/`encoding=` cuando la base los necesite)
# - `.head()`, `.shape`, `.columns`
# - Elegir columnas: `df[["col1", "col2"]]`
# - `.isna().sum()` (contar vacíos) y `.notna()` (filtrar por ellos — misma técnica de filtrar filas, con esta condición)

# %% [markdown]
# ### 💻 Lo que se espera que un estudiante escriba (ejemplo mínimo, con `guaguas`)

# %%
import pandas as pd

tabla = pd.read_csv("guaguas_maquillada.csv")
print("Filas y columnas:", tabla.shape)
print("Columnas:", list(tabla.columns))
tabla.head()

# %%
print("Nulos por columna:")
print(tabla[["n", "sexo"]].isna().sum())

tabla_sin_nulos_sexo = tabla[tabla["sexo"].notna()]
print("Filas después de filtrar sexo nulo:", len(tabla_sin_nulos_sexo))

# %% [markdown]
# ## 📝 Nota
#
# ⚠️ Decir explícito que pandas NO entra en la Evaluación de Funciones+Strings+Listas (fecha pendiente) — para no generar ansiedad antes de la prueba.
