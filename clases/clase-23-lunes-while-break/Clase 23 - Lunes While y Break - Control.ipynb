# %% [markdown]
# # ⚡ Clase 23 — Control de Ciclos
#
# **Fecha:** 2026-08-17
# **Nombre:** _______________________
# **Curso:** _______________________
#
# ---

# %% [markdown]
# ## 💪 Actitud del control: Perseverancia
#
# **En este control debemos perseverar hasta el último ítem.** Si algo no te sale a la primera, no lo dejes: sigue intentando antes de pasar al siguiente.

# %% [markdown]
# ## 📋 Antes de partir
#
# **Trabajo individual y con nota.** Escribe tu programa en la celda de cada ítem y entrega este notebook por Classroom antes de que termine la clase. No se pide que uses nombres de variable en particular: se revisa lo que tu programa hace, no cómo lo escribiste.
#
# **Tiempo:** 20 minutos · **Puntaje total:** 100 puntos

# %% [markdown]
# ---
#
# ## Ítem 1 — Batería del robot repartidor (25 pts)
#
# El robot que reparte libros en la biblioteca parte el día con 100 de batería. Cada entrega le descuenta una cantidad distinta, que el encargado va anotando, y el robot deja de aceptar entregas cuando la batería queda bajo 20.
#
# **El programa debe:**
# - Partir con la batería en 100.
# - Ir pidiendo cuánto consumió cada entrega y descontarlo.
# - Dejar de pedir entregas cuando la batería quede bajo 20.
# - Mostrar con cuánta batería terminó.
#
# **Ejemplo válido:**
#
# <p>📥 <em>El usuario ingresa:</em></p>
# <pre>30
# 25
# 40</pre>
# <p>📤 <em>El programa imprime:</em></p>
# <pre>El robot se detuvo con 5 de batería.</pre>

# %%
# Tu solución del Ítem 1

# %% [markdown]
# ---
#
# ## Ítem 2 — El primer video que despegó (30 pts)
#
# Una cuenta de TikTok revisa las vistas de sus últimos 8 videos, uno por uno. Apenas aparece el primero que supera las 5.000 vistas, deja de revisar y avisa cuál fue.
#
# **El programa debe:**
# - Revisar hasta 8 videos, pidiendo las vistas de cada uno.
# - Detenerse apenas uno supere las 5.000 vistas.
# - Mostrar el número del video que lo logró.
#
# **Ejemplo válido:**
#
# <p>📥 <em>El usuario ingresa:</em></p>
# <pre>1200
# 3400
# 6100</pre>
# <p>📤 <em>El programa imprime:</em></p>
# <pre>El video 3 superó las 5.000 vistas.</pre>

# %%
# Tu solución del Ítem 2

# %% [markdown]
# ---
#
# ## Ítem 3 — Máquina de reciclaje (45 pts)
#
# La máquina de reciclaje del supermercado suma 5 puntos por cada botella y entrega el vale al llegar a 20 puntos. Si le meten algo que no es botella, lo devuelve, no suma nada y queda esperando lo siguiente.
#
# **El programa debe:**
# - Ir pidiendo qué se ingresó a la máquina (`botella` u otra cosa).
# - Sumar 5 puntos solo por las botellas.
# - Dejar de pedir al llegar a los 20 puntos y mostrar el total.
#
# **Ejemplo válido:**
#
# <p>📥 <em>El usuario ingresa:</em></p>
# <pre>botella
# lata
# botella
# botella
# botella</pre>
# <p>📤 <em>El programa imprime:</em></p>
# <pre>Vale entregado con 20 puntos.</pre>

# %%
# Tu solución del Ítem 3

# %% [markdown]
# ---
#
# ## 🎯 Cierre — reflexión individual
#
# En este control, cuenta en qué ítem tuviste que aplicar la perseverancia y cómo se vio en lo que hiciste.
#
# *(Esta pregunta no lleva nota — respóndela con confianza.)*

# %% [markdown]
# ### 📝 Mi respuesta
#
# *(haz doble click para editar y escribir tu respuesta)*

# %% [markdown]
# ---
#
# ## ✅ Antes de entregar
#
# - Ejecuta cada celda una última vez para confirmar que tu programa corre.
# - Sube este mismo archivo a Classroom.
