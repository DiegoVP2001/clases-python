# %% [markdown]
# # 🐍 Clase 20 — For Anidado
#
# **Curso:** 4to medio  |  **Duración:** 80 min  |  **Plataforma:** Google Colab
#
# ---

# %% [markdown]
# ## 🎯 Objetivo de la clase
#
# Construir programas con ciclos `for` anidados que generen tablas y patrones organizados en filas y columnas, con orden.
#
# ## 💡 Propósito
#
# > El orden es organizar el trabajo en pasos claros, uno dentro de otro, sin mezclarlos. Hoy lo practicamos anidando ciclos `for`.
#
# ---
#
# **Lo que ya sabes:** Condicionales completos (if/else, if anidadas, elif) y ciclos `for` con `range()` (Clase N°16)
#
# **Lo que aprenderás hoy:** Ciclos `for` anidados (ciclo dentro de otro ciclo), relación filas/columnas entre ciclo externo e interno, sangría de dos niveles, construcción de salida por fila usando `print(..., end=...)` y `print()` vacío para el salto de línea

# %% [markdown]
# ---
#
# ## 1️⃣ Haz Ahora
#
# Propósito: activar la intuición de "repetir un patrón, y dentro de cada repetición, repetir otro patrón más chico" — sin código, en papel — antes de nombrarlo como concepto. Es spoiler sutil de la lógica de anidar, en lenguaje cotidiano, sin revelar sintaxis.
#
# Actividad: Una sala de cine tiene 4 filas de butacas, y cada fila tiene 5 asientos. En una celda markdown, respondiendo en un par de palabras, se les pide que describan cómo numerarían todos los asientos de la sala, butaca por butaca, sin saltarse ninguno — describiendo el "para cada fila... y dentro de cada fila...".

# %% [markdown]
# **Mis respuestas:**
#
# 1.
# 2.
# 3.

# %% [markdown]
# ---
#
# ## 2️⃣ Introducción al Contenido Nuevo
#
# Estudia cada concepto, ejecuta los ejemplos y observa el resultado:

# %% [markdown]
# ### 💡 Ciclo `for` anidado
#
# Un ciclo `for` dentro de otro ciclo `for`. El ciclo de adentro se ejecuta completo por cada vuelta del ciclo de afuera.
#
# **Idea clave:** _por cada vuelta del ciclo externo, el ciclo interno corre entero antes de que el externo avance._

# %%
for fila in range(1, 3):
    for asiento in range(1, 4):
        print("Fila", fila, "- Asiento", asiento)
# Out:
# Fila 1 - Asiento 1
# Fila 1 - Asiento 2
# Fila 1 - Asiento 3
# Fila 2 - Asiento 1
# Fila 2 - Asiento 2
# Fila 2 - Asiento 3

# %% [markdown]
# ### 💡 Filas y columnas
#
# en un `for` anidado, la variable del ciclo externo suele representar las filas, y la variable del ciclo interno representa las columnas dentro de cada fila.
#
# **Idea clave:** _pensar "primero fijo la fila, después recorro todas sus columnas" ayuda a decidir cuál `for` va afuera y cuál va adentro._

# %%
for fila in range(1, 3):
    for columna in range(1, 4):
        print("(", fila, ",", columna, ")")
# Out:
# ( 1 , 1 )
# ( 1 , 2 )
# ( 1 , 3 )
# ( 2 , 1 )
# ( 2 , 2 )
# ( 2 , 3 )

# %% [markdown]
# ### 💡 Sangría de dos niveles
#
# cada nivel de anidamiento exige su propia sangría. El cuerpo del `for` interno va indentado dentro del cuerpo del `for` externo.
#
# **Idea clave:** _perder la sangría del ciclo interno rompe la relación de anidamiento — Python deja de entender que uno está "dentro" del otro._

# %%
for fila in range(1, 3):
    print("Fila", fila)
    for asiento in range(1, 4):
        print("  Asiento", asiento)
# Out:
# Fila 1
#   Asiento 1
#   Asiento 2
#   Asiento 3
# Fila 2
#   Asiento 1
#   Asiento 2
#   Asiento 3

# %% [markdown]
# ### 💡 Construir la salida por fila
#
# usar `print(..., end=...)` dentro del ciclo interno mantiene los valores en la misma línea; un `print()` vacío después del ciclo interno (pero dentro del externo) salta a la siguiente línea al terminar cada fila.
#
# **Idea clave:** _sin el `print()` vacío al cierre de cada fila, toda la sala quedaría impresa en una sola línea corrida._

# %%
for fila in range(1, 3):
    for asiento in range(1, 4):
        print(asiento, end=" ")
    print()
# Out:
# 1 2 3
# 1 2 3

# %% [markdown]
# #### ⚠️ Errores típicos a evitar
#
# | Error | Qué ocurre | Cómo corregirlo |
# |---|---|---|
# | El ciclo interno no queda indentado dentro del externo | Ambos ciclos corren "en paralelo", no anidados — el resultado no forma una tabla | Verificar que el `for` interno esté un nivel de sangría más adentro que el externo |
# | Usar el mismo nombre de variable en ambos ciclos | La variable externa se sobrescribe y el conteo de filas se pierde | Usar nombres distintos para el índice de fila y el de columna |
# | Olvidar el salto de línea entre filas | Todos los asientos quedan impresos en una sola línea corrida | Agregar un `print()` vacío al terminar cada vuelta del ciclo externo |

# %% [markdown]
# ---
#
# ## 3️⃣ Práctica Guiada
#
# **Situación:** El colegio va a abrir inscripciones para talleres extraprogramáticos y necesita imprimir la grilla de horarios: hay 4 días de la semana con talleres, y cada día tiene 3 bloques horarios disponibles.
#
# **Antes de escribir código, analiza el enunciado:**
#
# <table>
# <tr><th>Qué debe hacer tu programa</th><th>Resultado esperado</th></tr>
# <tr>
# <td>1. Crea una variable que registre cuántos días de la semana tienen talleres, y otra que registre cuántos bloques horarios hay por día.</td>
# <td><pre>(todavía no hay output — son solo las cantidades iniciales)</pre></td>
# </tr>
# <tr>
# <td>2. Construye un ciclo que recorra cada día de la semana.</td>
# <td><pre>(todavía no hay output — el ciclo externo aún no imprime nada por sí solo)</pre></td>
# </tr>
# <tr>
# <td>3. Dentro de ese ciclo, construye otro ciclo que recorra cada bloque horario de ese día, mostrando en pantalla el número de día y el número de bloque, uno junto al otro en la misma línea.</td>
# <td><pre>Día 1 - Bloque 1  Día 1 - Bloque 2  Día 1 - Bloque 3</pre></td>
# </tr>
# <tr>
# <td>4. Al terminar de recorrer todos los bloques de un día, salta a una nueva línea antes de pasar al día siguiente.</td>
# <td><pre>Día 1 - Bloque 1  Día 1 - Bloque 2  Día 1 - Bloque 3
# Día 2 - Bloque 1  Día 2 - Bloque 2  Día 2 - Bloque 3
# Día 3 - Bloque 1  Día 3 - Bloque 2  Día 3 - Bloque 3
# Día 4 - Bloque 1  Día 4 - Bloque 2  Día 4 - Bloque 3</pre></td>
# </tr>
# </table>

# %%
# Tu programa

# %% [markdown]
# ---
#
# ## 4️⃣ Práctica Independiente
#
# Resuelve los siguientes ejercicios en pareja. Si se traban, pregunten al profe.

# %% [markdown]
# ### Ejercicio 1 — Torneo de tenis de mesa (obligatorio)
#
# Un campeonato de tenis de mesa entre cursos tiene 5 rondas, y en cada ronda se juegan tantos partidos como el número de la ronda (ronda 1 tiene 1 partido, ronda 2 tiene 2 partidos, y así). El programa debe mostrar cada partido de cada ronda, identificando el número de ronda y el número de partido dentro de esa ronda.
# Resultado esperado: una tabla creciente, donde la ronda 1 muestra 1 línea, la ronda 2 muestra 2 líneas, hasta la ronda 5 con 5 líneas.

# %%
# Tu solución del Ejercicio 1

# %% [markdown]
# ### Ejercicio 2 — Diseño de un tablero de ajedrez (Bonus — décimas extra)
#
# Un tablero de ajedrez tiene 8 filas y 8 columnas, alternando casillas claras y oscuras. El programa debe recorrer todas las casillas del tablero, fila por fila, mostrando en pantalla si cada casilla es clara u oscura según su posición.
# Resultado esperado: 8 líneas, cada una mostrando el patrón alternado de 8 casillas de esa fila.

# %%
# Tu solución del Ejercicio 2

# %% [markdown]
# ---
#
# ## 🎫 Ticket de Salida
#
# Las preguntas del Ticket de Salida se van a proyectar en la tele, una por una. Míralas, decide tu respuesta y espera a que pasen todas — recién al final completas y envías [este formulario](https://forms.gle/sjRpbgmQzrpkEBsH9) con tus respuestas.
#
# En el campo **"Tema de la clase de hoy"** escribe: `for avanzado`
#
# Cuando todos hayan enviado, revisamos juntos las respuestas correctas 🙌

# %% [markdown]
# ---
#
# ## 🎯 Cierre
#
# **Objetivo de la clase**
#
# Construir programas con ciclos `for` anidados que generen tablas y patrones organizados en filas y columnas, con orden.
#
# ---
#
# **Reflexiona antes de irte:**
#
# 1. ¿Qué tan seguro/a te sientes construyendo un `for` dentro de otro `for`? (1 = no entendí nada, 5 = puedo explicárselo a otro)
#
# 2. ¿En qué otra situación de tu vida (fuera de la programación) tendrías que organizar algo en filas y columnas, paso a paso y sin mezclar niveles?

# %% [markdown]
# ### 📝 Mis respuestas
#
# *(haz doble click para editar y escribir tus respuestas)*
#
# 1.
#
# 2.

# %% [markdown]
# ---
