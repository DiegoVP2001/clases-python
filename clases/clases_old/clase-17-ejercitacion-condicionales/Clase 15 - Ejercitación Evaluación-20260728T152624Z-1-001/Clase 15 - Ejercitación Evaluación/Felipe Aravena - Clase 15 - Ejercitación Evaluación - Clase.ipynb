# %% [markdown]
# # 🎯 Ejercitación Evaluación — Repaso para la Evaluación de Condicionales
#
# 📅 **Fecha:** 14/06/2026
# 👤 **Nombre:** Felipw Aravena
# 📌 **Curso:** 4to°MB
#
# **Vale hasta +6 décimas en total:** +1 décima por completar la Sección 1 (Calentamiento) y hasta +5 décimas en la Sección 2 (Programas completos).

# %% [markdown]
# ---
#
# ## 📋 Instrucciones
#
# - Escribe tu código en las celdas grises debajo de cada enunciado.
# - En la **Sección 1**, las variables ya están definidas — completa solo la línea que falta (o corrige el error, según corresponda).
# - Cada ítem de la Sección 1 ya trae su propia verificación al final de la misma celda: al ejecutarla (**Shift + Enter**) vas a ver de inmediato si tu respuesta está correcta.
# - **No modifiques los enunciados.**
# - Al terminar, comparte el Colab con el profesor desde el botón **Compartir**.

# %% [markdown]
# ---
#
# ## 🧭 Práctica Guiada — repaso del patrón `elif` con `if` anidado
#
# **Situación:** Un local registra el monto de una compra y si la persona tiene tarjeta de fidelización, para decidir qué descuento aplicar.
#
# ```python
# monto_compra = 12000
# tiene_tarjeta = True
# ```
#
# <table>
# <tr>
#   <th>Qué debe hacer tu programa</th>
#   <th>Resultado esperado</th>
# </tr>
# <tr>
#   <td>Paso 1: Crea las variables del monto y la tarjeta, y escribe el <code>if</code> para compras muy bajas (menos de \$5.000)</td>
#   <td><pre>(no se ejecuta con este monto — sigue evaluando)</pre></td>
# </tr>
# <tr>
#   <td>Paso 2: Agrega el <code>elif</code> para el rango medio (entre \$5.000 y \$19.999), y dentro de él anida un <code>if</code>/<code>else</code> según si tiene tarjeta</td>
#   <td><pre>Tienes 10% de descuento por ser socio.</pre></td>
# </tr>
# <tr>
#   <td>Paso 3: Cierra con el <code>else</code> final para compras de \$20.000 o más</td>
#   <td><pre>(no se ejecuta con este monto)</pre></td>
# </tr>
# </table>

# %%
# Tu programa
monto_compra = 12000
tiene_tarjeta = True

if monto_compra < 5000:
  print("No hay descuento pndjo")
  print("El precio a pagar seria",monto_compra)
elif monto_compra < 20000:
    if tiene_tarjeta:
      print("Tienes un 10% de descuento por ser soooocio papa,")
      print("El precio a pagar seria",(monto_compra * 0.9))
    else:
      print("No hay descuento pndjo")
      print("El precio a pagar seria",monto_compra)
else:
  print("No hay descuento pndjo")
  print("El precio a pagar seria",monto_compra)
# Out:
# Tienes un 10% de descuento por ser soooocio papa,
# El precio a pagar seria 10800.0

# %% [markdown]
# ---
#
# **🔧 Configuración** — ejecuta esta celda primero (Shift + Enter). No necesitas entender ni editar su contenido.

# %%
#@title 🔧 Configuración automática (no la edites)

def verificar_1A_1(valor):
    try:
        assert valor == False, "Revisa tu condición: el resultado no es el esperado para este caso."
        print("✅ ¡Muy bien! El ítem 1A.1 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1A_2(valor):
    try:
        assert valor == True, "Revisa tu condición: el resultado no es el esperado para este caso."
        print("✅ ¡Muy bien! El ítem 1A.2 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1A_3(valor):
    try:
        assert valor == False, "Revisa tu condición: el resultado no es el esperado para este caso."
        print("✅ ¡Muy bien! El ítem 1A.3 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1A_4(valor):
    try:
        assert valor == True, "Revisa tu condición: el resultado no es el esperado para este caso."
        print("✅ ¡Muy bien! El ítem 1A.4 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1A_5(valor):
    try:
        assert valor == False, "Revisa tu condición: el resultado no es el esperado para este caso."
        print("✅ ¡Muy bien! El ítem 1A.5 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1B_1(valor):
    try:
        assert valor == "Sala llena, no se puede vender más.", "El mensaje no coincide con el esperado para este caso — revisa el bug de nuevo."
        print("✅ ¡Muy bien! El ítem 1B.1 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1B_2(valor):
    try:
        assert valor == "Acceso concedido al laboratorio.", "El mensaje no coincide con el esperado para este caso — revisa el bug de nuevo."
        print("✅ ¡Muy bien! El ítem 1B.2 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1B_3(valor):
    try:
        assert valor == "Sala reservada con éxito.", "El mensaje no coincide con el esperado para este caso — revisa el bug de nuevo."
        print("✅ ¡Muy bien! El ítem 1B.3 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1B_4(valor):
    try:
        assert valor == "Debes esperar la asignación de equipo.", "El mensaje no coincide con el esperado para este caso — revisa el bug de nuevo."
        print("✅ ¡Muy bien! El ítem 1B.4 está correcto.")
    except AssertionError as e:
        print("❌", e)

def verificar_1B_5(valor):
    try:
        assert valor == "Categoría: Plata", "El mensaje no coincide con el esperado para este caso — revisa el bug de nuevo."
        print("✅ ¡Muy bien! El ítem 1B.5 está correcto.")
    except AssertionError as e:
        print("❌", e)

# %% [markdown]
# ---
#
# ## 🔥 Sección 1 — Calentamiento rápido
#
# Ítems cortos para repasar antes de los programas completos. Vale **+1 décima en bloque** si completas y pasas la verificación de los 10 ítems (1A + 1B).

# %% [markdown]
# ### 1A — Arma la condición
#
# Las variables ya están definidas. Escribe **solo la línea que falta** con la condición pedida y ejecuta para ver el resultado y la verificación.

# %% [markdown]
# ---
#
# **Ítem 1A.1** — `and` simple
#
# En el taller de música del liceo, puede sumarse al ensayo de hoy quien traiga su **instrumento** Y haya **confirmado asistencia** con anticipación.

# %%
tiene_instrumento = True
confirmo_asistencia = False

puede_ensayar = tiene_instrumento and confirmo_asistencia

print("¿Puede ensayar hoy?", puede_ensayar)
verificar_1A_1(puede_ensayar)
# Out:
# ¿Puede ensayar hoy? False
# ✅ ¡Muy bien! El ítem 1A.1 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1A.2** — `or` simple
#
# La feria de emprendedores de Isla de Maipo da **descuento** a quien sea **vecino de la comuna** O tenga **carnet de estudiante** vigente.

# %%
es_vecino_isla_maipo = False
tiene_carnet_estudiante = True

tiene_descuento = es_vecino_isla_maipo or tiene_carnet_estudiante

print("¿Tiene descuento en la feria?", tiene_descuento)
verificar_1A_2(tiene_descuento)
# Out:
# ¿Tiene descuento en la feria? True
# ✅ ¡Muy bien! El ítem 1A.2 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1A.3** — `var1 and (var2 or var3)`
#
# En el torneo de fútbol escolar, juega el partido quien esté **inscrito en el equipo** Y además (tenga la **camiseta oficial** O haya **pagado la cuota** del torneo).

# %%
esta_inscrito_equipo = True
tiene_camiseta_oficial = False
pago_cuota_torneo = False

puede_jugar = esta_inscrito_equipo and (tiene_camiseta_oficial or pago_cuota_torneo)

print("¿Puede jugar el partido?", puede_jugar)
verificar_1A_3(puede_jugar)
# Out:
# ¿Puede jugar el partido? False
# ✅ ¡Muy bien! El ítem 1A.3 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1A.4** — `(var1 and var2) or var3`
#
# La biblioteca del liceo presta libros a quien (sea **alumno regular** Y no tenga **multas pendientes**) O sea **profesor** del establecimiento.

# %%
es_alumno_regular = False
sin_multas_pendientes = True
es_profesor = True

puede_retirar_libro = (es_alumno_regular and sin_multas_pendientes) or es_profesor

print("¿Puede retirar el libro?", puede_retirar_libro)
verificar_1A_4(puede_retirar_libro)
# Out:
# ¿Puede retirar el libro? True
# ✅ ¡Muy bien! El ítem 1A.4 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1A.5** — `not(var1) and (var2 and var3)`
#
# El campeonato escolar de e-sports abre un cupo tardío para quien **NO** haya **seleccionado equipo** todavía, Y además (tenga una **cuenta válida** Y haya **aceptado el reglamento**).

# %%
ya_selecciono_equipo = False
tiene_cuenta_valida = True
acepto_reglamento = False

puede_inscribirse_tarde = not ya_selecciono_equipo and (tiene_cuenta_valida and acepto_reglamento)

print("¿Puede inscribirse en el cupo tardío?", puede_inscribirse_tarde)
verificar_1A_5(puede_inscribirse_tarde)
# Out:
# ¿Puede inscribirse en el cupo tardío? False
# ✅ ¡Muy bien! El ítem 1A.5 está correcto.

# %% [markdown]
# ### 1B — Arregla el bug
#
# Cada fragmento tiene un solo error. Corrígelo directamente en la misma celda y ejecuta para comprobar (la verificación ya está al final del código).

# %% [markdown]
# ---
#
# **Ítem 1B.1** — Bloque 3 — Análisis de condiciones (caso límite)
#
# El cine escolar considera la sala **llena** cuando se **alcanza** la capacidad máxima (no solo cuando la supera).

# %%
entradas_vendidas = 120
capacidad_maxima = 120

if entradas_vendidas >= capacidad_maxima:
    mensaje_cine = "Sala llena, no se puede vender más."
else:
    mensaje_cine = "Aún quedan entradas disponibles."

print(mensaje_cine)
verificar_1B_1(mensaje_cine)
# Out:
# Sala llena, no se puede vender más.
# ✅ ¡Muy bien! El ítem 1B.1 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1B.2** — Bloque 1 — Booleanos y comparaciones
#
# El sistema de acceso al laboratorio de computación compara la clave ingresada con la clave correcta.

# %%
clave_correcta = 4821
clave_ingresada = 4821

if clave_ingresada == clave_correcta:
    mensaje_lab = "Acceso concedido al laboratorio."
else:
    mensaje_lab = "Clave incorrecta."

print(mensaje_lab)
verificar_1B_2(mensaje_lab)
# Out:
# Acceso concedido al laboratorio.
# ✅ ¡Muy bien! El ítem 1B.2 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1B.3** — Bloque 4 — if / else
#
# El sistema de reservas de la sala de ensayo confirma la reserva si hay sala disponible.

# %%
hay_sala_disponible = True

if hay_sala_disponible:
    mensaje_sala = "Sala reservada con éxito."
else:
    mensaje_sala = "No hay salas disponibles hoy."

print(mensaje_sala)
verificar_1B_3(mensaje_sala)
# Out:
# Sala reservada con éxito.
# ✅ ¡Muy bien! El ítem 1B.3 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1B.4** — Bloque 5 — if anidados
#
# El taller de robótica revisa primero si estás inscrito, y solo entonces si ya tienes equipo de trabajo asignado.

# %%
esta_inscrito_taller = True
tiene_equipo_asignado = False

if esta_inscrito_taller:
    if tiene_equipo_asignado:
        mensaje_robotica = "Puedes comenzar tu proyecto de robótica."
    else:
        mensaje_robotica = "Debes esperar la asignación de equipo."
else:
    mensaje_robotica = "Primero debes inscribirte en el taller."

print(mensaje_robotica)
verificar_1B_4(mensaje_robotica)
# Out:
# Debes esperar la asignación de equipo.
# ✅ ¡Muy bien! El ítem 1B.4 está correcto.

# %% [markdown]
# ---
#
# **Ítem 1B.5** — Bloque 6 — elif
#
# El maratón de baile clasifica el puntaje en categorías. Recuerda: las condiciones deben ir ordenadas de la más específica a la más general.

# %%
puntaje_participante = 72

if puntaje_participante >= 80:
    mensaje_talento = "Categoría: Bronce"
elif puntaje_participante >= 60:
    mensaje_talento = "Categoría: Plata"
elif puntaje_participante >= 40:
    mensaje_talento = "Categoría: Oro"
else:
    mensaje_talento = "Categoría: Sin clasificar"

print(mensaje_talento)
verificar_1B_5(mensaje_talento)
# Out:
# Categoría: Plata
# ✅ ¡Muy bien! El ítem 1B.5 está correcto.

# %% [markdown]
# ---
#
# ## 💻 Sección 2 — Programas completos
#
# Ahora sí: programas completos desde una narrativa, igual que en la Clase 17 original. Aquí se juega el resto de las décimas.

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 1 — Kiosco escolar (+1 décima)
#
# El kiosco del colegio hace una promoción en el recreo: si el monto de la compra supera cierto mínimo, la persona se lleva una bebida de regalo. Escribe el programa que, dado el monto de la compra, informe si obtiene el regalo o no.
#
# **El programa debe:**
# - Registrar el **monto de la compra** como variable al inicio
# - Verificar si el monto **alcanza el mínimo** para el regalo (\$1.500)
# - Mostrar un **mensaje distinto** según corresponda
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario escribe</em><pre>monto_compra_kiosko = 1200</pre></td>
#   <td>📥 <em>El usuario escribe</em><pre>monto_compra_kiosko = 1800</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>Aún no alcanzas el monto para el regalo.</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>¡Compra premiada! Llévate una bebida de regalo.</pre></td>
# </tr>
# </table>

# %%
# Tu solución del Ejercicio 1
monto_compra_kiosco = int(input("Cuanto cuesta tu compra: "))

if monto_compra_kiosco >= 1500:
  print("Felicidades, ¡Compra premiada! llevese una bebida de regalo")
else:
  print("Aun no alcanzas el monto para el regalo")
# Out:
# Cuanto cuesta tu compra: 2
# Aun no alcanzas el monto para el regalo

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 2 — Audiciones del taller de teatro (+1 décima)
#
# El taller de teatro hace audiciones para la obra de fin de año. El sistema revisa dos cosas en orden: primero si la persona se inscribió a tiempo, y solo si lo hizo, si preparó un monólogo. Escribe el programa que informe el resultado según ambas condiciones.
#
# **El programa debe:**
# - Registrar si **se inscribió a tiempo** y si **preparó un monólogo**
# - Verificar primero si se **inscribió a tiempo**
# - Solo si se inscribió, verificar si **preparó el monólogo**
# - Mostrar un **mensaje distinto** para cada uno de los tres caminos posibles
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario escribe</em><pre>se_inscribio_a_tiempo = True
# preparo_monologo = False</pre></td>
#   <td>📥 <em>El usuario escribe</em><pre>se_inscribio_a_tiempo = False
# preparo_monologo = False</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>Inscrito, pero debes preparar un monólogo antes de audicionar.</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>Las inscripciones para la audición ya cerraron.</pre></td>
# </tr>
# </table>

# %%
# Tu solución del Ejercicio 2
se_inscribio_a_tiempo = input("Te inscribiste a tiempo waton? ")

if se_inscribio_a_tiempo == "True":
  preparo_monologo = input("Preparaste monologo waton? ")
  if preparo_monologo == "True":
    print("Inscrito, bienvenido a las audiciones ")
  elif preparo_monologo == "False":
    print("Inscrito, pero debes preparar un monólogo antes de audicionar")
  else:
    print("Escribe bien waton","\033[91m Eliminando system32 \033[0m")
elif se_inscribio_a_tiempo == "False":
  print("Las inscripciones para la audicion ya cerraron")
else:
  print("Escribe bien waton","\033[91m Eliminando system32 \033[0m")
# Out:
# Te inscribiste a tiempo waton? si
# Escribe bien waton  Eliminar system32

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 3 — Reloj del torneo de ajedrez (+1 décima)
#
# En un torneo de ajedrez escolar, el reloj de cada jugador clasifica su situación según los minutos restantes. Escribe el programa que, dados los minutos restantes, muestre la categoría correspondiente.
#
# **El programa debe:**
# - Registrar los **minutos restantes** del reloj como variable al inicio
# - Clasificar el estado usando **cuatro categorías** según el tiempo
# - Mostrar un **mensaje claro** con la categoría obtenida
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario escribe</em><pre>minutos_restantes_reloj = 3</pre></td>
#   <td>📥 <em>El usuario escribe</em><pre>minutos_restantes_reloj = 0</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>Zeitnot: quedan menos de 5 minutos.</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>Tiempo agotado: partida perdida por tiempo.</pre></td>
# </tr>
# </table>

# %%
# Tu solución del Ejercicio 3
minutos_restantes_reloj = int(input("Cuantos minutos te quedan? "))
if minutos_restantes_reloj < 1:
  print("Tiempo agotado: partida perdida por tiempo.")
elif minutos_restantes_reloj < 5:
  print("Zeitnot: quedan menos de 5 minutos")
elif minutos_restantes_reloj < 10:
  print("Quedan menos de 10 minutos")
else:
  print("Sigale nomas aun tienes mas de 10 minutos")

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 4 — Transporte compartido al concierto (desafío) (+2 décimas)
#
# Un grupo del liceo organiza transporte compartido en van para ir a un concierto, según cuántos cupos quedan disponibles. Cuando quedan pocos cupos, el sistema revisa además si la persona ya pagó la reserva, porque eso le da prioridad frente al resto. Escribe el programa que, dados los cupos restantes y si la persona pagó la reserva, muestre el resultado correspondiente.
#
# **El programa debe:**
# - Registrar los **cupos restantes** de la van y si **pagó la reserva**
# - Verificar primero si los cupos **se agotaron**
# - Si quedan **pocos cupos** (5 o menos), verificar además el **pago de la reserva**
# - Si quedan **muchos cupos**, mostrar que hay disponibilidad sin restricciones
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario escribe</em><pre>cupos_restantes_van = 4
# pago_reserva = True</pre></td>
#   <td>📥 <em>El usuario escribe</em><pre>cupos_restantes_van = 4
# pago_reserva = False</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>Tienes prioridad de cupo por tu reserva pagada.</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>Quedan pocos cupos — sin reserva pagada debes esperar confirmación.</pre></td>
# </tr>
# </table>

# %%
# Tu solución del Ejercicio 4
cupos_restantes_van = int(input("Los cupos restantes son: "))
if cupos_restantes_van < 1:
  print("Ya no quedan cupos :´) ")
elif cupos_restantes_van <= 5:
  pago_reserva = input("Pagaste la reserva? ")
  if pago_reserva == "True":
    print("Tienes prioridad de cupo por tu reserva pagada")
  elif pago_reserva == "False":
    print("Quedan pocos cupos - sin reserva pagaqda debes esperar confirmación")
  else:
    print("Escribe bien waton","\033[91m Eliminando system32 \033[0m")
else:
  print("Entren nomas, disponibilidad sin restricciones")
# Out:
# Los cupos restantes son: 0
# Ya no quedan cupos :´)

# %% [markdown]
# ---
#
# ## 🏁 Cierre
#
# Con esto repasaste los 7 bloques de la evaluación: booleanos, operadores lógicos, análisis de condiciones, if/else, if anidados, elif, y criterio de selección. Si te quedó algún bloque incómodo, repásalo antes del martes 21 de julio.
