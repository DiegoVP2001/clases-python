# %% [markdown]
# # 📝 Evaluación Individual — Condicionales (Reposición)
#
# **Fecha:** jueves 6 de agosto, 2026
#
# 📅 **Fecha:** ___________________________
# 👤 **Nombre:** Alain Moyano___________________________
# 📌 **Curso:** __3 medio b_________________________

# %% [markdown]
# ---
#
# ## 📋 Instrucciones generales
#
# - Esta evaluación tiene **2 secciones** y dura **75 minutos**.
# - Trabaja en orden y administra tu tiempo.
# - Entrega este notebook a través de **Google Classroom** antes de que termine la clase.
# - El código debe ejecutarse sin errores. Si no terminas un ejercicio, deja lo que alcanzaste.
# - Usa nombres de variables en **snake_case en español**.
# - Cuando un ejercicio pida un dato con `input()`, el enunciado siempre aclara si es un **número entero**, un **número con decimales**, o una **palabra exacta**.
# - **Prohibido** copiar código de compañeros.

# %% [markdown]
# ---
#
# ## 📊 Distribución de puntaje (total 100 pts)
#
# | Ítem | Contenido | Puntaje |
# |---|---|---|
# | 1.1 | Kilometraje semanal de natación | 18 pts |
# | 1.2 | Batería del control de PS5 | 12 pts |
# | 1.3 | Entrada a la Fiesta de la Vendimia | 24 pts |
# | 1.4 | Convención de videojuegos y anime | 16 pts |
# | 2A.1 | Arma la condición | 4 pts |
# | 2A.2 | Arma la condición | 4 pts |
# | 2B.1 | Arregla el bug | 4 pts |
# | 2B.2 | Arregla el bug | 5 pts |
# | 2B.3 | Arregla el bug | 4 pts |
# | 2B.4 | Arregla el bug | 4 pts |
# | 2B.5 | Arregla el bug | 5 pts |
# | **Total** | | **100 pts** |

# %% [markdown]
# ---
#
# ## 💻 Sección 1 — Programas completos (70 pts)
#
# Programas completos desde una narrativa. Cada uno pide sus datos con `input()` — lee bien el tipo de dato que se espera antes de escribir tu código.

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 1 — Kilometraje semanal de natación (18 pts)
#
# El club de natación de la piscina municipal registra cuántos kilómetros nada cada estudiante en la semana, para reconocer la constancia de cada nadador. Escribe el programa que, dado el kilometraje nadado, muestre el nivel correspondiente.
#
# **El programa debe:**
# - Pedir con `input()` los **kilómetros nadados esta semana** (**puede tener decimales**)
# - Clasificar el kilometraje en estos 4 niveles:
#   - Menos de 5 km → `"Nivel: Recién empezando."`
#   - Entre 5 y menos de 15 km → `"Nivel: En camino."`
#   - Entre 15 y menos de 25 km → `"Nivel: Buen ritmo."`
#   - 25 km o más → `"Nivel: ¡Semana destacada!"`
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario ingresa</em><pre>8</pre></td>
#   <td>📥 <em>El usuario ingresa</em><pre>27.5</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>Nivel: En camino.</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>Nivel: ¡Semana destacada!</pre></td>
# </tr>
# </table>

# %%
# Tu solución — Ejercicio 1
personas_contador= 0
while personas_contador <=149:
  personas_contador +=1

print("personas ingresadas:",personas_contador, )
# Out:
# personas ingresadas: 150

# %%
# Tu solución del Ejercicio 1

personas_contador = 0

while personas_contador <= 149:
    personas_contador += 1

print("personas ingresadas:", personas_contador)
# Out:
# personas ingresadas: 150

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 2 — Batería del control de PS5 (12 pts)
#
# La app de un control de PlayStation revisa el nivel de batería antes de cada partida: si queda suficiente carga, activa el Modo Turbo con vibración avanzada; si no, deja el control en modo ahorro de energía. Escribe el programa que, dado el porcentaje de batería, informe en qué modo queda el control.
#
# **El programa debe:**
# - Pedir con `input()` el **porcentaje de batería del control** (**un número entero** entre 0 y 100)
# - Verificar si la batería **alcanza el mínimo** para el Modo Turbo (70)
# - Mostrar un **mensaje distinto** según corresponda
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario ingresa</em><pre>70</pre></td>
#   <td>📥 <em>El usuario ingresa</em><pre>45</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>¡Modo Turbo activado! 🎮</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>Modo ahorro de energía.</pre></td>
# </tr>
# </table>

# %%
# Tu solución del Ejercicio
personas_contador = 0

while personas_contador < 150:
    personas_contador += 1
    print("Persona ingresada:", personas_contador)

print("personas ingresadas:", personas_contador)
# Out:
# Persona ingresada: 1
# Persona ingresada: 2
# Persona ingresada: 3
# Persona ingresada: 4
# Persona ingresada: 5
# Persona ingresada: 6
# Persona ingresada: 7
# Persona ingresada: 8
# Persona ingresada: 9
# Persona ingresada: 10
# Persona ingresada: 11
# Persona ingresada: 12
# Persona ingresada: 13
# Persona ingresada: 14
# Persona ingresada: 15
# Persona ingresada: 16
# Persona ingresada: 17
# Persona ingresada: 18
# Persona ingresada: 19
# Persona ingresada: 20
# Persona ingresada: 21
# Persona ingresada: 22
# Persona ingresada: 23
# Persona ingresada: 24
# Persona ingresada: 25
# Persona ingresada: 26
# Persona ingresada: 27
# Persona ingresada: 28
# Persona ingresada: 29
# Persona ingresada: 30
# Persona ingresada: 31
# Persona ingresada: 32
# Persona ingresada: 33
# Persona ingresada: 34
# Persona ingresada: 35
# Persona ingresada: 36
# Persona ingresada: 37
# Persona ingresada: 38
# Persona ingresada: 39
# Persona ingresada: 40
# Persona ingresada: 41
# Persona ingresada: 42
# ...

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 3 — Entrada a la Fiesta de la Vendimia (24 pts)
#
# La boletería de la Fiesta de la Vendimia de Isla de Maipo arma el acceso según el tipo de entrada. Para la entrada VIP, además revisa si la persona lleva un acompañante, porque eso cambia el acceso que recibe. Escribe el programa que, dado el tipo de entrada y —cuando corresponda— si lleva acompañante, muestre a qué acceso queda.
#
# **El programa debe:**
# - Pedir con `input()` el **tipo de entrada** (la persona responde **exactamente** una de estas palabras: "general", "preferencial" o "vip")
# - Si el tipo es **"vip"**, pedir además con `input()` si **lleva acompañante** (responde **exactamente** "si" o "no") — esta pregunta no se hace para los otros tipos
# - Mostrar el mensaje que corresponda a cada uno de estos casos:
#   - tipo "general" → `"Acceso por la fila general."`
#   - tipo "preferencial" → `"Acceso por la fila preferencial."`
#   - tipo "vip" sin acompañante → `"Acceso VIP directo."`
#   - tipo "vip" con acompañante → `"Acceso VIP directo con acompañante."`
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario ingresa</em><pre>vip<br>si</pre></td>
#   <td>📥 <em>El usuario ingresa</em><pre>preferencial</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>Acceso VIP directo con acompañante.</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>Acceso por la fila preferencial.</pre></td>
# </tr>
# </table>

# %%
# Tu solución del Ejercicio 3
tipo_entrada = input("Ingrese el tipo de entrada: ")

if tipo_entrada == "general":
    print("Acceso por la fila general.")

elif tipo_entrada == "preferencial":
    print("Acceso por la fila preferencial.")

elif tipo_entrada == "vip":
    acompanante = input("¿Lleva acompañante? ")

    if acompanante == "si":
        print("Acceso VIP directo con acompañante.")
    else:
        print("Acceso VIP directo.")
# Out:
# Ingrese el tipo de entrada: vip
# ¿Lleva acompañante? si
# Acceso VIP directo con acompañante.

# %% [markdown]
# ---
#
# ## 🎯 Ejercicio 4 — Convención de videojuegos y anime (16 pts)
#
# Para entrar a una convención de videojuegos y anime, el sistema revisa primero si la persona ya compró su entrada digital; si no la compró, revisa si el efectivo que lleva alcanza para pagar la entrada en la puerta. Escribe el programa que, según esos datos, muestre cómo puede entrar la persona.
#
# **El programa debe:**
# - Pedir con `input()` si ya tiene **entrada digital comprada** (la persona responde **exactamente** "si" o "no")
# - Si **no** tiene entrada digital, pedir además con `input()` **cuánto efectivo lleva** (un **número entero**, en pesos)
# - Verificar primero la entrada digital; solo si no la tiene, verificar si el efectivo **alcanza** el costo de la entrada en la puerta (\$6.000)
# - Mostrar el mensaje que corresponda a cada uno de estos tres caminos:
#   - Tiene entrada digital → `"Ingresa directo mostrando su entrada digital."`
#   - No tiene entrada Y el efectivo alcanza → `"Paga la entrada en la puerta."`
#   - No tiene entrada Y el efectivo no alcanza → `"No le alcanza el efectivo para entrar."`
#
# <table>
# <tr>
#   <th>Ejemplo 1</th>
#   <th>Ejemplo 2</th>
# </tr>
# <tr>
#   <td>📥 <em>El usuario ingresa</em><pre>si</pre></td>
#   <td>📥 <em>El usuario ingresa</em><pre>no<br>4000</pre></td>
# </tr>
# <tr>
#   <td>📤 <em>El programa imprime</em><pre>Ingresa directo mostrando su entrada digital.</pre></td>
#   <td>📤 <em>El programa imprime</em><pre>No le alcanza el efectivo para entrar.</pre></td>
# </tr>
# </table>

# %%
# Tu solución del Ejercicio 4
entrada_digital = input("¿Tiene entrada digital comprada? ")

if entrada_digital == "si":
    print("Ingresa directo mostrando su entrada digital.")
else:
    efectivo = int(input("¿Cuánto efectivo lleva? "))

    if efectivo >= 6000:
        print("Paga la entrada en la puerta.")
    else:
        print("No le alcanza el efectivo para entrar.")
# Out:
# ¿Tiene entrada digital comprada? no
# ¿Cuánto efectivo lleva? 6000
# Paga la entrada en la puerta.

# %% [markdown]
# ---
#
# ## 🔥 Sección 2 — Ítems cortos (30 pts)
#
# Repaso rápido de condicionales, dividido en dos partes.

# %% [markdown]
# ### 2A — Arma la condición
#
# Las variables ya están definidas. Escribe **solo la línea que falta** con la condición pedida.

# %% [markdown]
# ---
#
# **Ítem 2A.1** (4 pts)
#
# Un sistema de riego automático en una parcela de Isla de Maipo solo abre la **válvula de riego por goteo** cuando el sensor detecta que la **tierra está seca** Y además hay **agua disponible en el canal**.

# %%
tierra_esta_iseca = True
hay_agua_en_canal = False

abre_valvula_riego = tierra_esta_iseca and hay_agua_en_canal

print("¿Abre la válvula de riego?", abre_valvula_riego)
# Out:
# ¿Abre la válvula de riego? False

# %% [markdown]
# ---
#
# **Ítem 2A.2** (4 pts)
#
# Para desbloquear el **modo cooperativo secreto** de un videojuego, se necesita tener el **nivel mínimo de cuenta** Y además (haber **completado el modo historia** O tener un **código de invitación** de un amigo).

# %%
tiene_nivel_minimo_cuenta = True
completo_modo_historia = False
tiene_codigo_invitacion = True

desbloquea_modo_cooperativo = tiene_nivel_minimo_cuenta and (completo_modo_historia or tiene_codigo_invitacion)

print("¿Desbloquea el modo cooperativo secreto?", desbloquea_modo_cooperativo)
# Out:
# ¿Desbloquea el modo cooperativo secreto? True

# %% [markdown]
# ### 2B — Arregla el bug
#
# Cada fragmento tiene un solo error. Corrígelo directamente en la misma celda.

# %% [markdown]
# ---
#
# **Ítem 2B.1** (4 pts)
#
# El **casillero inteligente** del gimnasio del liceo solo se abre cuando el **código ingresado** es exactamente igual al **código asignado** al estudiante.

# %%
codigo_asignado = 4821
codigo_ingresado = 4821

if codigo_ingresado == codigo_asignado:
    mensaje_casillero = "Casillero abierto."
else:
    mensaje_casillero = "Código incorrecto, casillero bloqueado."

print(mensaje_casillero)
# Out:
# Casillero abierto.

# %% [markdown]
# ---
#
# **Ítem 2B.2** (5 pts)
#
# En un juego de estrategia online, una alianza declara la **victoria** en la batalla cuando su cantidad de **tropas** **alcanza** el mínimo necesario para ganar (no solo cuando lo supera).

# %%
tropas_alianza = 500
tropas_minimas_victoria = 500

if tropas_alianza >= tropas_minimas_victoria:
    mensaje_batalla = "La alianza gana la batalla."
else:
    mensaje_batalla = "La alianza pierde la batalla."

print(mensaje_batalla)
# Out:
# La alianza gana la batalla.

# %% [markdown]
# ---
#
# **Ítem 2B.3** (4 pts)
#
# Antes de enviar una tarea en la **plataforma de estudio en línea**, el sistema revisa si el **archivo fue adjuntado** correctamente.

# %%
archivo_adjuntado = True

if archivo_adjuntado:
    mensaje_plataforma = "Tarea enviada con éxito."
else:
    mensaje_plataforma = "Falta adjuntar el archivo."

print(mensaje_plataforma)
# Out:
# Tarea enviada con éxito.

# %% [markdown]
# ---
#
# **Ítem 2B.4** (4 pts)
#
# Un **dron de reparto** revisa primero si tiene **batería suficiente** para volar, y solo entonces si **detectó la dirección de entrega**.

# %%
bateria_suficiente = True
detecto_direccion_entrega = False

if bateria_suficiente:
    if detecto_direccion_entrega:
        mensaje_dron = "El dron entrega el paquete."
    else:
        mensaje_dron = "El dron no encontró la dirección."
else:
    mensaje_dron = "El dron no puede despegar por batería baja."

print(mensaje_dron)
# Out:
# El dron no encontró la dirección.

# %% [markdown]
# ---
#
# **Ítem 2B.5** (5 pts)
#
# Una **tienda de artículos de skate** clasifica el nivel de **fidelidad** de un cliente según la cantidad de **compras acumuladas en el año**, de la categoría más exigente a la más básica.

# %%
compras_acumuladas_anio = 12

if compras_acumuladas_anio >= 14:
    mensaje_fidelidad = "Cliente VIP."
elif compras_acumuladas_anio >= 7:
    mensaje_fidelidad = "Cliente frecuente."
elif compras_acumuladas_anio >= 3:
    mensaje_fidelidad = "Cliente ocasional."
else:
    mensaje_fidelidad = "Nuevo cliente."

print(mensaje_fidelidad)
# Out:
# Cliente frecuente.

# %% [markdown]
# ---
#
# ## 🏁 Fin de la evaluación
#
# Revisa que todas las celdas se ejecuten sin errores antes de compartir el Colab.
