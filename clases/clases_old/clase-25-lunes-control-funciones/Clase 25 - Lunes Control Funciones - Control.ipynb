# %% [markdown]
# # ⚡ Clase 25 — Control de Funciones
#
# **Fecha:** 2026-08-24
# **Nombre:** _______________________
# **Curso:** _______________________
#
# ---

# %% [markdown]
# ## 💪 Actitud del control: Confianza en el proceso
#
# **En este control, confía en el proceso.** Sigue siempre el mismo orden — define, consulta los datos, evalúa guardando el resultado en una variable, e imprime — no te lo saltes aunque el ítem se vea corto o distinto a los anteriores.

# %% [markdown]
# ## 📋 Antes de partir
#
# **Trabajo individual y con nota.** Escribe tu programa en la celda de cada ítem y entrega este notebook por Classroom antes de que termine la clase. No se pide que uses nombres de variable en particular: se revisa lo que tu programa hace, no cómo lo escribiste.
#
# **Tiempo:** 20 minutos · **Puntaje total:** 100 puntos

# %% [markdown]
# ---
#
# ## Ítem 1 — Piscina municipal de Isla de Maipo en verano (25 pts)
#
# La piscina municipal de Isla de Maipo tiene un aforo máximo fijado por seguridad, y el guardavidas quiere saber al instante cuántos cupos quedan disponibles cada vez que entra o sale gente, sin tener que calcularlo a mano.
#
# **El programa debe:**
# - Definir una función que reciba el aforo máximo y la cantidad de personas que están dentro, y devuelva cuántos cupos quedan disponibles con `return`.
# - Pedir esos dos datos.
# - Llamar la función, guardar el resultado en una variable, y mostrar cuántos cupos quedan disponibles.
#
# <details>
# <summary>💡 Pista — Resta simple, sin condicional</summary>
#
# Los cupos disponibles son el aforo máximo menos las personas que están dentro ahora.
#
# </details>
#
# **Ejemplo válido:**
#
# <p>📥 <em>El usuario ingresa:</em></p>
# <pre>60
# 45</pre>
# <p>📤 <em>El programa imprime:</em></p>
# <pre>Cupos disponibles: 15</pre>

# %%
# Tu solución del Ítem 1

# %% [markdown]
# ---
#
# ## Ítem 2 — Bingo solidario del Centro de Padres (30 pts)
#
# El Centro de Padres organiza un bingo solidario: venden cartones a un precio fijo, y al cerrar la jornada quieren saber cuánto les quedó de ganancia después de pagar el arriendo del salón.
#
# **El programa debe:**
# - Definir una función que reciba la cantidad de cartones vendidos y el precio de cada cartón, y devuelva el ingreso total con `return`.
# - Pedir esos dos datos, llamar la función y guardar el ingreso en una variable.
# - Pedir cuánto costó el arriendo del salón y restárselo al ingreso guardado para obtener la ganancia.
# - Mostrar la ganancia final.
#
# <details>
# <summary>💡 Pista — Guarda el ingreso antes de restar el arriendo</summary>
#
# Primero calcula y guarda el ingreso total (cartones por precio) en una variable; el arriendo se pide y se resta después, no dentro de la función.
#
# </details>
#
# **Ejemplo válido:**
#
# <p>📥 <em>El usuario ingresa:</em></p>
# <pre>80
# 500
# 15000</pre>
# <p>📤 <em>El programa imprime:</em></p>
# <pre>Ganancia del bingo: 25000</pre>

# %%
# Tu solución del Ítem 2

# %% [markdown]
# ---
#
# ## Ítem 3 — Pedido de arcilla para el taller de cerámica (45 pts)
#
# El taller de cerámica compra arcilla por kilo para todo el semestre, y el proveedor ofrece un descuento total según la cantidad de kilos que pidan de una sola vez: mientras más kilos, mayor el descuento.
#
# **El programa debe:**
# - Definir una función que reciba la cantidad de kilos pedidos y devuelva el descuento que corresponde con `return`: \$5.000 de descuento si piden 20 kilos o más, \$2.000 si piden entre 10 y 19, y sin descuento si piden menos de 10.
# - Pedir la cantidad de kilos y el precio de cada kilo, y calcular aparte el total bruto (kilos por precio).
# - Llamar la función, guardar el descuento, y restárselo al total bruto para obtener el total final.
# - Mostrar el total final a pagar.
#
# <details>
# <summary>💡 Pista 1 — El total bruto no depende de la función</summary>
#
# Calcula kilos por precio por fuera de la función; la función solo decide el descuento según los kilos.
#
# </details>
#
# <details>
# <summary>💡 Pista 2 — Los tramos son "o más"</summary>
#
# Usa `>=` para los límites de 20 y 10 kilos, no `>`.
#
# </details>
#
# **Ejemplo válido:**
#
# <p>📥 <em>El usuario ingresa:</em></p>
# <pre>20
# 2000</pre>
# <p>📤 <em>El programa imprime:</em></p>
# <pre>Total a pagar: 35000</pre>

# %%
# Tu solución del Ítem 3

# %% [markdown]
# ---
#
# ## 🎯 Cierre — reflexión individual
#
# Cuenta un momento en que aplicaste confianza en el proceso durante este control. ¿Qué habría pasado con tu resultado si no lo hacías justo ahí?
#
# *(Esta pregunta no lleva nota — respóndela con confianza.)*

# %% [markdown]
# ### 📝 Mi respuesta
#
# *(haz doble click para editar y escribir tu respuesta)*

# %% [markdown]
# ---
#
# ## ✅ Antes de entregar
#
# - Ejecuta cada celda una última vez para confirmar que tu programa corre.
# - Sube este mismo archivo a Classroom.
