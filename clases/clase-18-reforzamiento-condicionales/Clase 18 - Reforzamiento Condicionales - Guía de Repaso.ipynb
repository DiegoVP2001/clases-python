# %% [markdown]
# # 🔁 Repaso Express — elif y combinaciones
#
# Guía corta antes de la evaluación del **martes 21 de julio**. Se enfoca solo en `elif` y en combinarlo con `if` anidados — lo último que se vio en Clase 17 y a lo que menos parejas llegaron.
#
# **Cómo usarla:**
# 1. Resuelve los **Ítems 1 a 3**, el **Desafío final** y los **Propuestos** por tu cuenta.
# 2. Revisa tus respuestas con la sección de soluciones al final del documento — ábrelas recién después de intentarlo. No hay corrección automática: lo importante es que la **lógica** y el **resultado** calcen, aunque el texto exacto de tu `print` sea distinto.

# %% [markdown]
# ---
#
# ## 🧩 Ítem 1
#
# Recuerda: solo se ejecuta la **primera** condición que sea `True`, de arriba hacia abajo — el orden importa.
#
# Una app de clima clasifica la temperatura de hoy en un nivel de alerta, para sugerir cómo vestirse antes de salir.
#
# **El programa debe:**
# - Clasificar `temperatura_grados` en **4 niveles**: helada (menor a 0°), fría (menor a 15°), templada (menor a 25°) y calurosa (25° o más)
# - Mostrar el mensaje correspondiente al nivel

# %%
temperatura_grados = 3

# Tu solución del Ítem 1

# %% [markdown]
# ---
#
# ## 🧩 Ítem 2
#
# Recuerda: el `if` anidado va **dentro** de una sola rama del `elif`, no reemplaza a las demás.
#
# Una plataforma de streaming musical arma el mensaje de bienvenida según el plan de la persona. Si el plan es **premium**, revisa además si activó el audio en alta calidad (HD), porque eso cambia el mensaje.
#
# **El programa debe:**
# - Distinguir entre plan `"basico"`, `"estandar"` y `"premium"`
# - Si el plan es `"premium"`, verificar además si `audio_hd_activado` es `True`
# - Mostrar el mensaje correspondiente

# %%
plan_streaming = "premium"
audio_hd_activado = True

# Tu solución del Ítem 2

# %% [markdown]
# ---
#
# ## 🐛 Ítem 3
#
# Una veterinaria clasifica la urgencia de una mascota según sus síntomas, y si es **urgente**, revisa además si hay un turno disponible ahora mismo. El fragmento de abajo tiene **un solo error** — corrígelo directamente en la celda.

# %%
nivel_sintomas = "urgente"
turno_disponible = False

if nivel_sintomas == "leve":
    mensaje_veterinaria = "Puede esperar a una hora normal."
elif nivel_sintomas == "moderado":
    mensaje_veterinaria = "Se recomienda ver hoy mismo."
elif nivel_sintomas == "urgente":
    if turno_disponible:
    mensaje_veterinaria = "Atención inmediata: hay turno disponible ahora."
    else:
        mensaje_veterinaria = "Urgencia: dirígete a la clínica de emergencia."

print("Mensaje de la veterinaria:", mensaje_veterinaria)

# %% [markdown]
# ---
#
# ## 🏁 Desafío final
#
# El sistema de notas del liceo entrega un mensaje según el promedio semestral. Si el promedio cae en el tramo más alto, revisa además si la asistencia es completa, porque eso habilita el ingreso al cuadro de honor.
#
# **El programa debe:**
# - Clasificar `promedio_semestral` en 4 tramos: insuficiente (menor a 4.0), aprobado (menor a 5.5), muy bueno (menor a 6.5) y destacado (6.5 o más)
# - Si el promedio es destacado, verificar además si `asistencia_completa` es `True` para el cuadro de honor
# - Mostrar el mensaje correspondiente
#
# Después de que te funcione con `promedio_semestral = 6.7` y `asistencia_completa = True`, cambia `asistencia_completa` a `False` y vuelve a ejecutar — el mensaje debería cambiar.

# %%
promedio_semestral = 6.7
asistencia_completa = True

# Tu solución del Desafío final

# %% [markdown]
# ---
#
# ## 🌟 Propuestos
#
# Dos ejercicios opcionales, un poco más largos, para quien quiera seguir practicando.

# %% [markdown]
# **Propuesto 1.** El celular avisa sobre el nivel de batería, y si está en nivel **crítico** revisa si el modo ahorro está activado, porque eso cambia cuánto tiempo más durará.
#
# **El programa debe:**
# - Clasificar `nivel_bateria` en 3 tramos: bueno (50% o más), medio (20% o más) y crítico (menos de 20%)
# - Si es crítico, verificar además si `modo_ahorro_activado` es `True`
# - Mostrar el mensaje correspondiente

# %%
nivel_bateria = 15
modo_ahorro_activado = True

# Tu solución del Propuesto 1

# %% [markdown]
# **Propuesto 2.** Una tienda de streaming de películas aplica descuentos según el tipo de cuenta. Si la cuenta es **nueva**, revisa si la persona ingresó un código promocional válido, porque eso le da un descuento extra el primer mes.
#
# **El programa debe:**
# - Distinguir entre cuenta `"nueva"` y `"antigua"` (cualquier otro valor es "no reconocida")
# - Si la cuenta es `"nueva"`, verificar además si `codigo_promocional_valido` es `True`
# - Mostrar el mensaje correspondiente

# %%
tipo_cuenta = "nueva"
codigo_promocional_valido = False

# Tu solución del Propuesto 2

# %% [markdown]
# ---
#
# **✅ Soluciones**
#
# Ábrelas recién después de intentar cada una tú mismo/a. Los mensajes pueden estar redactados distinto a los tuyos — lo que importa es que la lógica y el resultado calcen.
#
# <details>
# <summary>💡 Solución Ítem 1</summary>
#
# ```python
# temperatura_grados = 3
#
# if temperatura_grados < 0:
#     print("Alerta: ¡Abrígate mucho, viene helada!")
# elif temperatura_grados < 15:
#     print("Frío: lleva chaqueta.")
# elif temperatura_grados < 25:
#     print("Templado: con polerón basta.")
# else:
#     print("Calor: usa ropa liviana.")
# >> Frío: lleva chaqueta.
# ```
# </details>
#
# <details>
# <summary>💡 Solución Ítem 2</summary>
#
# ```python
# plan_streaming = "premium"
# audio_hd_activado = True
#
# if plan_streaming == "basico":
#     print("Plan básico: audio estándar.")
# elif plan_streaming == "estandar":
#     print("Plan estándar: sin anuncios.")
# elif plan_streaming == "premium":
#     if audio_hd_activado:
#         print("Premium HD: la mejor calidad disponible.")
#     else:
#         print("Premium: audio estándar, activa el HD cuando quieras.")
# >> Premium HD: la mejor calidad disponible.
# ```
# </details>
#
# <details>
# <summary>💡 Solución Ítem 3</summary>
#
# ```python
# nivel_sintomas = "urgente"
# turno_disponible = False
#
# if nivel_sintomas == "leve":
#     mensaje_veterinaria = "Puede esperar a una hora normal."
# elif nivel_sintomas == "moderado":
#     mensaje_veterinaria = "Se recomienda ver hoy mismo."
# elif nivel_sintomas == "urgente":
#     if turno_disponible:
#         mensaje_veterinaria = "Atención inmediata: hay turno disponible ahora."
#     else:
#         mensaje_veterinaria = "Urgencia: dirígete a la clínica de emergencia."
#
# print("Mensaje de la veterinaria:", mensaje_veterinaria)
# >> Mensaje de la veterinaria: Urgencia: dirígete a la clínica de emergencia.
# ```
#
# El error era de indentación: la línea `mensaje_veterinaria = "Atención inmediata..."` debía ir **dentro** del `if turno_disponible:`, con un nivel más de sangría.
# </details>
#
# <details>
# <summary>💡 Solución Desafío final</summary>
#
# ```python
# promedio_semestral = 6.7
# asistencia_completa = True
#
# if promedio_semestral < 4.0:
#     print("Promedio insuficiente: exigencia mínima 4.0.")
# elif promedio_semestral < 5.5:
#     print("Promedio aprobado: sigue así.")
# elif promedio_semestral < 6.5:
#     print("Muy buen promedio: ¡felicitaciones!")
# else:
#     if asistencia_completa:
#         print("¡Cuadro de honor! Promedio destacado y asistencia perfecta.")
#     else:
#         print("Promedio destacado, pero te faltó asistencia perfecta para el cuadro de honor.")
# >> ¡Cuadro de honor! Promedio destacado y asistencia perfecta.
# ```
#
# Con `asistencia_completa = False`, el mensaje cambia a "Promedio destacado, pero te faltó asistencia perfecta..." — aunque el promedio sea el mismo.
# </details>
#
# <details>
# <summary>💡 Solución Propuesto 1</summary>
#
# ```python
# nivel_bateria = 15
# modo_ahorro_activado = True
#
# if nivel_bateria >= 50:
#     print("Batería en buen nivel.")
# elif nivel_bateria >= 20:
#     print("Batería media: considera cargar pronto.")
# else:
#     if modo_ahorro_activado:
#         print("Batería crítica, pero el modo ahorro está activo: aguanta más tiempo.")
#     else:
#         print("Batería crítica: carga el celular ahora.")
# >> Batería crítica, pero el modo ahorro está activo: aguanta más tiempo.
# ```
# </details>
#
# <details>
# <summary>💡 Solución Propuesto 2</summary>
#
# ```python
# tipo_cuenta = "nueva"
# codigo_promocional_valido = False
#
# if tipo_cuenta == "nueva":
#     if codigo_promocional_valido:
#         print("Bienvenida con 50% de descuento el primer mes.")
#     else:
#         print("Bienvenida con 20% de descuento el primer mes.")
# elif tipo_cuenta == "antigua":
#     print("Sin descuento por renovación.")
# else:
#     print("Tipo de cuenta no reconocida.")
# >> Bienvenida con 20% de descuento el primer mes.
# ```
# </details>

# %% [markdown]
# ---
#
# ## 🏁 Cierre
#
# Repasando y ejercitando así, te va a ir increíble en la evaluación del martes 21. ¡Confía en tu proceso y nos vemos ese día! 💪
