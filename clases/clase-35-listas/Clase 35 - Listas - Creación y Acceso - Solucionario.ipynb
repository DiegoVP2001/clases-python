# %% [markdown]
# # 🔒 Solucionario — Clase 35: Listas: Creación y Acceso
#
# **Uso:** documento exclusivo para el profesor. El Ticket de Salida se proyecta en clase y se responde a viva voz; el resto (Haz Ahora, Guiada, Independiente) es para revisar en vivo o subir a Classroom recién **después** de dictar la clase — nunca antes.
#
# ---

# %% [markdown]
# ## 1️⃣ Haz Ahora — Respuestas
#
# 1. 2ª posición
# 2. 3267
# 3. 2021 y Mateo
#
# ---
#
# ## 3️⃣ Práctica Guiada — Solución
#
# ```python
# fila = "2021,Emma,F,2352"
# datos = fila.split(",")
#
# print("Nombre:", datos[1])
# cantidad = int(datos[3])
# print("El doble de las inscripciones:", cantidad * 2)
# print("Año y nombre juntos:", datos[0:2])
# ```
#
# ---
#
# ## 4️⃣ Práctica Independiente — Soluciones
#
# ### Ejercicio 0a — Práctica directa: convertir y acceder por índice
#
# ```python
# fila = "2021,Sofía,F,2251"
# datos = fila.split(",")
# print("Año:", datos[0])
# print("Nombre:", datos[1])
# ```
#
# ### Ejercicio 1 — El registro más antiguo
#
# ```python
# fila = "1920,Aaron,M,1"
# datos = fila.split(",")
# print("Nombre:", datos[1])
# print("Sexo registrado:", datos[-2])
# ```
#
# ### Ejercicio 2 — Dos años iguales
#
# ```python
# fila = "2021,Julieta,F,1723"
# datos = fila.split(",")
# print("Año y nombre:", datos[0:2])
# cantidad = int(datos[3])
# print("Inscripciones en dos años iguales:", cantidad + cantidad)
# ```
#
# ### Ejercicio 3 — ¿Son la misma persona?
#
# ```python
# fila_1 = "2021,Emilia,F,2044"
# fila_2 = "2021,Emiliano,M,1357"
# datos_1 = fila_1.split(",")
# datos_2 = fila_2.split(",")
#
# print("Nombre 1:", datos_1[1])
# print("Nombre 2:", datos_2[1])
#
# cantidad_1 = int(datos_1[3])
# cantidad_2 = int(datos_2[3])
# print("Diferencia de inscripciones:", cantidad_1 - cantidad_2)
# ```
#
# ### Ejercicio 4 — Desafío: ¿cuánto le faltó?
#
# ```python
# fila_1 = "2021,Mateo,M,3267"
# fila_2 = "2021,Emma,F,2352"
# datos_1 = fila_1.split(",")
# datos_2 = fila_2.split(",")
#
# print("Fila completa 1:", datos_1)
# print("Fila completa 2:", datos_2)
# print("Año y nombre del segundo lugar:", datos_2[0:2])
#
# cantidad_1 = int(datos_1[3])
# cantidad_2 = int(datos_2[3])
# print("Le faltaron:", cantidad_1 - cantidad_2)
# ```
#
# ---

# %% [markdown]
# ## 🎫 Ticket de Salida

# %% [markdown]
# ### Pregunta 1
#
# ```python
# fila = "2021,Sofía,F,2251"
# datos = fila.split(",")
# print(datos[-1])
# ```
#
# ¿Qué imprime este programa?
#
# **A:** `2021`
#
# **B:** `Sofía`
#
# **C:** `F`
#
# **D:** `2251` ✅
#
# > 💡 El índice -1 apunta al último dato de la lista, que es la cantidad.

# %% [markdown]
# ### Pregunta 2
#
# ```python
# fila = "2021,Sofía,F,2251"
# datos = fila.split(",")
# print(datos[0:2])
# ```
#
# ¿Qué imprime este programa?
#
# **A:** `['2021', 'Sofía']` ✅
#
# **B:** `['2021', 'Sofía', 'F']`
#
# **C:** `['Sofía', 'F']`
#
# **D:** `['2021']`
#
# > 💡 El slicing `[0:2]` incluye el índice 0 pero excluye el índice 2, así que llega solo hasta el índice 1.

# %% [markdown]
# ### Pregunta 3
#
# ```python
# fila = "2021,Sofía,F,2251"
# datos = fila.split(",")
# print(datos[3] * 2)  # <- esta línea
# ```
#
# ¿Qué imprime la línea marcada?
#
# **A:** `4502`
#
# **B:** `22512251` ✅
#
# **C:** Error, porque no se puede multiplicar
#
# **D:** `2251`
#
# > 💡 `datos[3]` es texto (`"2251"`), no un número — multiplicar un string por 2 lo repite, no lo multiplica.
