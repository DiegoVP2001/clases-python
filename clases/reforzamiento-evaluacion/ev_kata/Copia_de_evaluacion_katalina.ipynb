# %% [markdown]
# # 📝 Evaluación de Programación
# ## **¡Vamos que se puede!**
# **Variables y operaciones básicas**
#
# Escribe tu nombre:Katalina Dominguez

# %% [markdown]
# Katalina
#
# ```
# # Esto tiene formato de código
# ```

# %% [markdown]
# ---
#
# ## Instrucciones
#
# - Esta evaluación tiene **5 ejercicios**.
# - Trabaja en orden y tómate tu tiempo.
# - Entrega este notebook a través de **Google Classroom** antes de que termine la clase.
# - El código debe ejecutarse sin errores. Si no terminas un ejercicio, deja lo que alcanzaste.
# - Usa los nombres de variables que se indican en cada ejercicio.
#
# ---
#
# ## Distribución de puntaje
#
# | Ejercicio | Contenido | Puntaje |
# |-----------|-----------|--------|
# | 1 | Variables de texto + print() | 20 pts |
# | 2 | Calcular e imprimir | 20 pts |
# | 3 | Promedio de gastos | 20 pts |
# | 4 | Renombrar variables | 20 pts |
# | 5 | Cálculo completo | 20 pts |
# | **Total** | | **100 pts** |

# %% [markdown]
# ---
# ## Ejercicio 1 — Variables de texto + print() (20 pts)
#
# Define las siguientes variables con tu información personal y luego imprímelas con `print()`.
#
# Los nombres de las variables que debes usar son: `mi_nombre`, `mi_ciudad` y `comida_favorita`.
#
# **El programa debe imprimir los tres valores, uno por línea.**

# %%
# Ejercicio 1 — Escribe tu código aquí
mi_nombre = "katalina"
mi_ciudad = "isla de maipo"
comida_favorita = "lasaña"

print (mi_nombre)
print (mi_ciudad)
print (comida_favorita)
# Out:
# katalina
# isla de maipo
# lasaña

# %% [markdown]
# ---
# ## Ejercicio 2 — Calcular e imprimir (20 pts)
#
# En la feria del colegio se vendieron poleras a **$4.990** cada una.
# Se vendieron **3 poleras** en total.
#
# Calcula el total recaudado e imprímelo.

# %%
# Ejercicio 2
precio_unitario = 4990
cantidad = 3

# Calcula el total aquí:
total = 14970

# Imprime el total:
print (precio_unitario + precio_unitario + precio_unitario )
# Out:
# 14970

# %% [markdown]
# ---
# ## Ejercicio 3 — Promedio de gastos (20 pts)
#
# Valentina anotó cuánto gastó en el quiosco del colegio durante tres días:
# - Lunes: **$1.500**
#
# - Miércoles: **$2.000**
#
# - Viernes: **$800**
#
# Calcula cuánto gastó en promedio por día.

# %%
# Ejercicio 3

# Paso 1: Define el gasto de cada día
gasto_lunes = 1500
gasto_miercoles = 2000
gasto_viernes = 800

# Paso 2: Suma los tres gastos
suma_gastos = gasto_lunes + gasto_miercoles + gasto_viernes

# Paso 3: Divide la suma en 3 para obtener el promedio
promedio_diario = suma_gastos/3

# Paso 4: Imprime el resultado
print (promedio_diario)
# Out:
# 1433.3333333333333

# %% [markdown]
# ---
# ## Ejercicio 4 — Renombrar variables (20 pts)
#
# Micaela trabajó **12 días** este mes. Su **pago por día es de $25.000**.
# El programa calcula su **sueldo total del mes**.
#
# El código de abajo funciona correctamente, pero los nombres de las variables (`x`, `y`, `z`) no dicen nada.
#
# **Cámbialos por nombres descriptivos en `snake_case` que reflejen lo que representa cada variable.**
# No puedes cambiar los valores ni las operaciones — solo los nombres.

# %%
# Ejercicio 4 — Reescribe el código con nombres descriptivos

este_mes = 12
pago_por_dia = 25000
valores = 12 * 25000
print (este_mes * pago_por_dia)
# Out:
# 300000

# %% [markdown]
# ---
# ## Ejercicio 5 — Cálculo completo (20 pts)
#
# Felipe trabaja en una frutería los sábados.
# Gana **$3.500 por hora** y este sábado trabajó **4 horas**.
#
# Escribe un programa que calcule cuánto ganó Felipe e imprima el resultado.

# %%
# Ejercicio 5

# Paso 1: Define las dos variables (pago por hora y horas trabajadas)
cuanto_gana = 3500
horas_trabajadas = 4

# Paso 2: Calcula lo que ganó Felipe
total = 14000

# Paso 3: Imprime el resultado
print (cuanto_gana * horas_trabajadas)
# Out:
# 14000
