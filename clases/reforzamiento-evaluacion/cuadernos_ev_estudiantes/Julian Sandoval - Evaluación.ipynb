# %% [markdown]
# # 📝 Evaluación de Programación — Clases 1 a 7
# **Jueves — 80 minutos**
#
# Escribe tu nombre:

# %% [markdown]
# Julian Sandoval

# %% [markdown]
# ---
#
# ## Instrucciones generales
#
# - Esta evaluación tiene **7 ejercicios** y dura **80 minutos**.
# - Trabaja **en orden** y administra tu tiempo.
# - Entrega este notebook a través de **Google Classroom** antes de que termine la clase.
# - El código debe ejecutarse sin errores. Si no terminas un ejercicio, deja lo que alcanzaste.
# - Usa nombres de variables en **snake_case en español** (`precio_total`, `horas_trabajadas`).
# - **Prohibido** copiar código de compañeros.
#
# ---
#
# ## Distribución de puntaje
#
# | Ejercicio | Contenido | Dificultad | Puntaje |
# |-----------|-----------|------------|---------|
# | 1 | Variables + print() | ⭐ Fácil | 10 pts |
# | 2 | print() con sep | ⭐ Fácil | 10 pts |
# | 3 | Actualización de variables | ⭐⭐ Media | 15 pts |
# | 4 | input() + porcentajes | ⭐⭐ Media | 15 pts |
# | 5 | input() + cálculo multi-paso | ⭐⭐ Media | 15 pts |
# | 6 | Depuración (sintaxis + lógica + indentación) | ⭐⭐ Media | 15 pts |
# | 7 | Integración | ⭐⭐⭐ Difícil | 20 pts |
# | **Total** | | | **100 pts** |

# %% [markdown]
# ---
# ## Ejercicio 1 — Promedio de notas ⭐ (10 pts)
#
# Define 3 variables con notas entre 1.0 y 7.0 y calcula su promedio.
#
# **El programa debe imprimir con `print()`:**
# ```
# Nota 1: 5.5
# Nota 2: 6.2
# Nota 3: 4.8
# Promedio: 5.5
# ```
#
# *Los valores de las notas pueden ser distintos.*

# %%
# Ejercicio 1 — Promedio de notas
# Escribe tu código aquí
nota1 = 5.5
nota2 = 6.2
nota3 = 4.8
promedio = (nota1 + nota2 + nota3) / 3
print("Nota 1:", nota1)
print("Nota 2:", nota2)
print("Nota 3:", nota3)
print("Promedio:", promedio)
# Out:
# Nota 1: 5.5
# Nota 2: 6.2
# Nota 3: 4.8
# Promedio: 5.5

# %% [markdown]
# ---
# ## Ejercicio 2 — Reporte de ventas de feria escolar ⭐ (10 pts)
#
# Las variables con los datos ya están definidas. Escribe los `print()` para que el reporte se vea exactamente así.
#
# **El programa debe imprimir con `print()`:**
# ```
# 🛍️ REPORTE DE VENTAS — FERIA ESCOLAR
# Producto | Unidades vendidas | Precio unitario
# Empanadas | 45 | $800
# Bebidas | 60 | $500
# Sopaipillas | 30 | $300
# Total recaudado: $ 63000
# ```

# %%
# Ejercicio 2 — Reporte de ventas de feria escolar
# Los datos ya están definidos — escribe los print() correctos

producto_1 = "Empanadas"
unidades_1 = 45
precio_1 = 800

producto_2 = "Bebidas"
unidades_2 = 60
precio_2 = 500

producto_3 = "Sopaipillas"
unidades_3 = 30
precio_3 = 300

total_recaudado = (unidades_1 * precio_1) + (unidades_2 * precio_2) + (unidades_3 * precio_3)

print("🛍️ REPORTE DE VENTAS — FERIA ESCOLAR")
print("Producto", "Unidades vendidas", "Precio unitario", sep = "|" )
print("Empanadas",unidades_1, precio_1, sep="|" ) 
print("Bebidas", unidades_1, precio_2, sep ="|" )
print("Sopaipillas", unidades_3, precio_3, sep = "|" )
print("Total recaudado: ", total_recaudado)
# Out:
# 🛍️ REPORTE DE VENTAS — FERIA ESCOLAR
# Producto|Unidades vendidas|Precio unitario
# Empanadas|45|800
# Bebidas|45|500
# Sopaipillas|30|300
# Total recaudado:  75000

# %% [markdown]
# ---
# ## Ejercicio 3 — Simulador de ahorro mensual ⭐⭐ (15 pts)
#
# Escribe un programa que simule los siguientes movimientos de una cuenta de ahorro:
#
# 1. Saldo inicial: $20.000
# 2. Depósito de sueldo: +$85.000
# 3. Pago de arriendo: −$45.000
# 4. Compra de supermercado: −$18.000
# 5. Depósito de bono: +$10.000
# 6. Pago de servicios básicos: −$8.500
#
# Puedes usar la forma detallada (`variable = variable + valor`) o los operadores abreviados (`+=`, `-=`). Ambas son válidas.
#
# **El programa debe imprimir con `print()`:**
# ```
# Saldo inicial: $ 20000
# Tras sueldo: $ 105000
# Tras arriendo: $ 60000
# Tras supermercado: $ 42000
# Tras bono: $ 52000
# Saldo final: $ 43500
# ```

# %%
# Ejercicio 3 — Simulador de ahorro mensual
saldo_inicial = 20000
print("Saldo inicial:", saldo_inicial)
saldo_inicial += 85000
tras_sueldo = saldo_inicial
print("Tras sueldo:", saldo_inicial)

saldo_inicial -= 45000
tras_arriendo = saldo_inicial
print("Tras arriendo:", saldo_inicial)

saldo_inicial -=  18000
tras_supermercado = saldo_inicial
print("Tras supermercado:", saldo_inicial)

saldo_inicial += 10000
deposito = saldo_inicial
print("Tras bono:", deposito)

saldo_inicial -= 8500
pago_servicios_basicos = saldo_inicial
print("Saldo final:", saldo_inicial)
# Out:
# Saldo inicial: 20000
# Tras sueldo: 105000
# Tras arriendo: 60000
# Tras supermercado: 42000
# Tras bono: 52000
# Saldo final: 43500

# %% [markdown]
# ---
# ## Ejercicio 4 — Calculadora de descuento en tienda ⭐⭐ (15 pts)
#
# **El programa debe pedir con `input()`:**
# - El precio original del producto
# - El porcentaje de descuento
#
# **El programa debe imprimir con `print()`:**
# ```
# --- RESUMEN DEL DESCUENTO ---
# Precio original: $ 59990.0
# Descuento (20%): $ 11998.0
# Precio final: $ 47992.0
# ```

# %%
# Ejercicio 4 — Calculadora de descuento en tienda
# Escribe tu código aquí
# Out:
# None
# 59989.8 hfj

# %% [markdown]
# ---
# ## Ejercicio 5 — Repartir ganancias del puesto de dulces ⭐⭐ (15 pts)
#
# Tú y tus compañeros pusieron un puesto de dulces en el liceo.
# Al final del día cuentan el dinero, restan lo que gastaron en insumos
# y se reparten lo que sobra en partes iguales.
# La ganancia neta es la diferencia entre lo recaudado y lo gastado en insumos.
#
# **El programa debe pedir con `input()`:**
# - El total recaudado durante el día
# - El total gastado en insumos (golosinas, bolsas, etc.)
# - La cantidad de personas en el puesto
#
# **El programa debe imprimir con `print()`:**
# ```
# --- REPARTO DEL PUESTO ---
# Total recaudado: $ 42000.0
# Gastos en insumos: $ 18000.0
# Ganancia neta: $ 24000.0
# Integrantes: 4
# Ganancia por persona: $ 6000.0
# ```

# %%
total_recaudado = input("Total Recaudado durante el dia:", "total recaudado" )
gastos_insumos = input("Gastos en insumos:", "gastos insumos")
cantidad_personas = input("Integrantes:", "cantidad de personas")
ganancia_neta = (total_recudado - gastos_insumos)
ganancia_persona = ganancia_neta / 4
print("--- REPARTO DEL PUESTO ---")
print("Total recaudado:", total_recaudado)
print("Gastos en insumos:", gastos_insumos)
print("Ganancia neta:", ganancia_neta)
print("Integrantes:", cantidad_personas)
print("Ganancia por persona:", ganancia_persona)
# Out:
# Total Recaudado durante el dia:
# Gastos en insumos:
# Integrantes:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       2 gastos_insumos = input("Gastos en insumos:", "gastos insumos")
#       3 cantidad_personas = input("Integrantes:", "cantidad de personas")
# ----> 4 ganancia_neta = (total_recudado - gastos_insumos)
#       5 ganancia_persona = ganancia_neta / 4
#       6 print("--- REPARTO DEL PUESTO ---")
#
# NameError: name 'total_recudado' is not defined

# %% [markdown]
# ---
# ## Ejercicio 6 — Depurar cálculo de nota ponderada ⭐⭐ (15 pts)
#
# El siguiente programa tiene **4 errores**. Encuéntralos y corrígelos sin cambiar los valores.
#
# **El programa debe imprimir con `print()`:**
# ```
# 📋 CÁLCULO DE NOTA FINAL
# Controles (35%): 5.8
# Módulo (30%): 6.4
# Proyecto (20%): 7.0
# Participación (15%): 5.5
# Nota final ponderada: 6.175
# ```
#
# Verificación: 5.8×0.35 + 6.4×0.30 + 7.0×0.20 + 5.5×0.15 = 6.175

# %%
# Ejercicio 6 — Depurar cálculo de nota ponderada
# Este código tiene 4 errores. Corrígelos sin cambiar los valores.

nota_controles = 5.8
nota_modulo = 6.4
nota_proyecto = 7.0
nota_participacion = 5.5

nota_final = (nota_controles * 0.35) + (nota_modulo * 0.30) + (nota_proyecto * 0.20) + (nota_participacion * 0.15)

print("📋 CÁLCULO DE NOTA FINAL")
print("Controles (35%):", nota_controles)
print("Módulo (30%):", nota_modulo)
print("Proyecto (20%):", nota_proyecto)
print("Participación (15%)", nota_participacion)
print("Nota final ponderada:", nota_final)
# Out:
# 📋 CÁLCULO DE NOTA FINAL
# Controles (35%): 5.8
# Módulo (30%): 6.4
# Proyecto (20%): 7.0
# Participación (15%) 5.5
# Nota final ponderada: 6.175

# %% [markdown]
# ---
# ## Ejercicio 7 — Registro semanal de gastos ⭐⭐⭐ (20 pts)
#
# **El programa debe pedir con `input()`:**
# - El presupuesto semanal disponible
# - El gasto del lunes
# - El gasto del martes
# - El gasto del miércoles
# - El gasto del jueves
# - El gasto del viernes
#
# **El programa debe imprimir con `print()`:**
# ```
# --- RESUMEN SEMANAL ---
# Presupuesto inicial: $ 30000
# Total gastado: $ 22500
# Saldo restante: $ 7500
# Porcentaje gastado: 75.0 %
# ```

# %%
# Ejercicio 7 — Registro semanal de gastos
# Escribe tu código aquí
