# %% [markdown]
# # 🐍 Semana 1 — Miércoles
# ## Taller: variables, operaciones y el arte de nombrar bien
#
# ---
#
# **Objetivo de hoy:** Crear código para situaciones cotidianas con operaciones matemáticas
#
# **Propósito:** Un código que funciona pero que nadie entiende es como si no funciona. Hoy entrenamos los dos: que funcione Y que se entienda.
#
# > 📓 **Importante:** Anota en tu cuaderno los errores que corrijas hoy y lo que aprendiste de ellos.

# %% [markdown]
# ---
# ## 👀 REVISIÓN EXPRÉS

# %% [markdown]
# Un estudiante quiere calcular el precio final de unas zapatillas que cuestan **$59.990** y tienen un **20% de descuento**. Para eso, escribió este código:
#
# ```python
# precio zapatilla = 59990
# d = 0.20
# x = precio zapatilla * (1 - d)
# print(x)
# ```
# Antes de ejecutarlo, analicemos en conjunto:
# 1. ¿Qué intenta calcular este código?
# 2. ¿Qué problemas tienen los nombres de las variables?
# 3. ¿Cómo podríamos reescribirlo para que el código funcione y sea más claro?
#
# Agregra una línea de código para responder

# %% [markdown]
# El código intenta

# %% [markdown]
# 1. grsgrdhtfjukgkuigukuygkuygkuygkuygkuygkuyg

# %%
precio zapatilafdjlkfa = 345934

# %%
precio_zapatilla = 59990
descuento = 0.20
valor_final = precio zapatilla * (1 - descuento)
print(valor_final)

# %% [markdown]
# ---
# ## ✍ Mi promedio de notas
# Utilizando variables, calcularemos el promedio de un curso en el cual netemos 4 notas.

# %%
nota1  = 6.5
segunda_nota

suma_de_notas = +  + + +

promedio = suma_de_notas/4
print(promedio)

# %% [markdown]
# ---
# ## 🛠️ DESAFÍO 1 — Calculadora de Barbero
#
# Barbero cobra **\$2.500** por corte. Trabaja **6 días a la semana** y hace un promedio de **8 cortes por día**. Pero gasta **\$15.000 semanales** en materiales.
#
# Calcula:
# 1. Su ingreso bruto semanal
# 2. Su ingreso neto semanal (descontando materiales)
# 3. Su ingreso neto mensual (considera 4 semanas)

# %%
# DESAFÍO 1

# %% [markdown]
# ---
# ## 🛠️ DESAFÍO 2 — Promedio ponderado
#
# En este curso las evaluaciones tienen estos pesos:
# - Controles semanales: **35%**
# - Evaluaciones de módulo: **30%**
# - Proyecto final: **20%**
# - Participación: **15%**
#
# Un estudiantes tiene: controles `6.2`, módulo `5.8`, proyecto `6.5`, participación `7.0`.
#
# Calcula e imprime su promedio final ponderado.

# %%
# DESAFÍO 2

# %% [markdown]
# ---
# ## 🐛 DESAFÍO 3 — Debugging de legibilidad
#
# Este programa **funciona correctamente**, pero está escrito de forma confusa. **No puedes cambiar lo que calcula — solo los nombres de las variables.**
#
# 1. Ejecuta el original y anota qué hace
# 2. Renombra todas las variables con `snake_case` y nombres descriptivos
# 3. Verifica que el resultado sea idéntico

# %%
# CÓDIGO ORIGINAL — ejecuta primero
x = 8
y = 5000
z = x * y
w = 0.13
q = z * (1 - w)
print(q)

# ¿Qué calcula?
#

# %%
# CÓDIGO MEJORADO — mismo resultado, mejores nombres

# %% [markdown]
# ## 🐛 DESAFÍO 4 — Debugging mixto
#
# Este código tiene **3 errores**: dos de sintaxis y uno de lógica.
#
# 1. Identifica los 3
# 2. Corrígelos en la celda de abajo
# 3. Describe cada error en el comentario

# %%
# Contexto: calcular el precio con descuento de una camiseta de $15.990 con 20% off

precio original = 15990
descuento = 20
precio_final = precio_original + descuento
print(precio_final)

# %%
# VERSIÓN CORREGIDA



# Error 1:
# Error 2:
# Error 3:

# %% [markdown]
# ---
# ## 🛠️ DESAFÍO 5 — Conversión de unidades
#
# Un estudiante corre **10 km** en **52 minutos**.
#
# Calcula:
# 1. Su velocidad promedio en **km/h** *(pista: convierte minutos a horas primero)*
# 2. Su **ritmo** en minutos por km *(tiempo total / distancia)*
# 3. Si mantiene ese ritmo, ¿cuántos minutos tardaría en una **media maratón (21.1 km)**?

# %%
# DESAFÍO 5

# %% [markdown]
# ---
# ## 🛠️ DESAFÍO 6 — Variable que se actualiza
#
# Un estudiante empieza el mes con **\$80.000**. Ocurren estas transacciones en orden:
#
# 1. Gana **\$35.000** por un trabajo
# 2. Gasta **\$12.500** en comida
# 3. Gasta **\$8.000** en transporte
# 4. Recibe **\$5.000** que le debían
# 5. Compra zapatillas por **\$29.990**
#
# Usa **una sola variable** `saldo` que se vaya actualizando. Imprime el saldo después de cada operación.

# %%
# DESAFÍO 6

# %% [markdown]
# ---
# ## 🐛 DESAFÍO 7 — Error lógico sutil
#
# Este código **no tiene errores de sintaxis** — ejecuta sin problema. Pero el resultado es incorrecto. Encuentra el error lógico y corrígelo.
#
# *(El resultado correcto para base=8, altura=5 es 20.0)*

# %%
# Contexto: calcular el área de un triángulo (base * altura / 2)
base = 8
altura = 5
area = base * altura / 3
print(area)

# ¿Cuál era el error?
#

# %%
# VERSIÓN CORREGIDA

# %% [markdown]
# ---
# ## 🛠️ DESAFÍO 8 — Reto integrador
#
# Un estudiante quiere saber si le alcanza el dinero para un concierto del viernes.
#
# Datos:
# - Tiene **\$25.000** en la cuenta
# - La entrada cuesta **\$8.000**
# - El transporte ida y vuelta cuesta **\$3.200**
# - Quiere llevar **\$10.000** para gastar dentro
# - El domingo tiene que pagar el colectivo: **\$1.500**
#
# Calcula:
# 1. El gasto total del fin de semana
# 2. Lo que le sobra (o le falta) después de todo
# 3. Si le falta, ¿cuánto necesita conseguir?
#
# El programa debe imprimir un mensaje claro con el resultado.

# %%
# DESAFÍO 8

# %% [markdown]
# ---
# ## 💪 Último opcional
#
# Trabaja solo/a. Elige **uno**:
#
# **Reto A:** Crea un programa que calcule tu promedio ponderado real en el curso usando las ponderaciones reales. Usa notas reales o inventadas.
#
# **Reto B:** Piensa en un cálculo de al menos 4 pasos que tenga sentido en tu vida. Escríbelo completo con variables bien nombradas.

# %%
# Reto elegido: A / B

# %% [markdown]
# ---
# ## 🪞 CIERRE — Metacognición
#
# Responde con honestidad. Esto no tiene nota.

# %%
# ¿Qué fue lo más difícil de hoy y cómo lo resolví?
#

# ¿Qué aprendí del trabajo en dupla que no hubiera aprendido solo/a?
#

# ¿Hay algo que todavía no me queda claro?
#

# %% [markdown]
# ---
# > 📋 **Ticket de salida** — El profe lo proyecta en la pizarra al final.
